# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#slightly open

positive = [['(S2) B 1050', 0.11633020241447431], ['(RBD) A 454', 0.11845338977994571], ['(S2) B 1097', 0.12642024279625497],
    ['(S2) C 876', 0.1276371318232088], ['(S2) B 1064', 0.13550222304010887], ['(RBD) A 492', 0.1426728352386988], 
    ['(RBD) A 493', 0.1459878243050767],
    ['(NTD) A 253', 0.20024619905770213], ['(RBD) A 455', 0.2155295911108682], ['(NTD) C 188', 0.3538040029908008]]

#positive.reverse()

positive = list(zip(*positive))

positive
# Out:
# [('(S2) B 1050',
#   '(RBD) A 454',
#   '(S2) B 1097',
#   '(S2) C 876',
#   '(S2) B 1064',
#   '(RBD) A 492',
#   '(RBD) A 493',
#   '(NTD) A 253',
#   '(RBD) A 455',
#   '(NTD) C 188'),
#  (0.11633020241447431,
#   0.11845338977994571,
#   0.12642024279625497,
#   0.1276371318232088,
#   0.13550222304010887,
#   0.1426728352386988,
#   0.1459878243050767,
#   0.20024619905770213,
#   0.2155295911108682,
#   0.3538040029908008)]

# %%
negative = [['B 6 (NTD)', -0.2846665437102131], ['C 1097 (S2)', -0.28380874603868406], ['A 155 (NTD)', -0.28260201591511985],
    ['C 1082 (S2)', -0.15313306126647186], ['A 1095 (S2)', -0.1384018563518239], ['B 624 (linker)', -0.1289372899808133], ['C 1074 (S2)', -0.12795134841871392],
    ['B 607 (linker)', -0.12028765675229887], ['B 256 (NTD)', -0.11265500702637041], ['C 1002 (S2)', -0.11217130036630858]]



negative = list(zip(*negative))

negative
# Out:
# [('B 6 (NTD)',
#   'C 1097 (S2)',
#   'A 155 (NTD)',
#   'C 1082 (S2)',
#   'A 1095 (S2)',
#   'B 624 (linker)',
#   'C 1074 (S2)',
#   'B 607 (linker)',
#   'B 256 (NTD)',
#   'C 1002 (S2)'),
#  (-0.2846665437102131,
#   -0.28380874603868406,
#   -0.28260201591511985,
#   -0.15313306126647186,
#   -0.1384018563518239,
#   -0.1289372899808133,
#   -0.12795134841871392,
#   -0.12028765675229887,
#   -0.11265500702637041,
#   -0.11217130036630858)]

# %%
fig, ax = plt.subplots(figsize=(4,4))
ax.tick_params(axis="y",direction="in", pad=-90)
ax.barh(positive[0], positive[1],color='orange')
plt.xlim(-0.3,0.4)
plt.axvline(x=0.0,ls='--',c='k')
plt.axvline(x=0.2,ls='--',c='k')
#plt.xticks(color='white')
plt.savefig('centrality_slight_positive.pdf',bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(4,4))
ax.yaxis.tick_right()
ax.tick_params(axis="y",direction="in", pad=-120)
ax.barh(negative[0], negative[1],color='orange')
plt.xlim(-0.3,0.4)
plt.axvline(x=0.0,ls='--',c='k')
plt.axvline(x=-0.2,ls='--',c='k')

plt.savefig('centrality_slight_negative.pdf',bbox_inches='tight')

# %%
#partially open
positive = [['(RBD) C 381', 0.11413242962188311], ['(RBD) C 382', 0.11811020199490596], ['(RBD) C 383', 0.1186025116576454], ['(RBD) C 438', 0.13107605333495354], ['(S2) C 187', 0.13266329625028064], 
            
    ['(RBD) B 454', 0.1554692878263608], ['(RBD) B 455', 0.20105242289947703], ['(S2) B 757', 0.21207823878987558], ['(NTD) C 98', 0.21932937949434242]]

positive = list(zip(*positive))

positive
# Out:
# [('(RBD) C 381',
#   '(RBD) C 382',
#   '(RBD) C 383',
#   '(RBD) C 438',
#   '(S2) C 187',
#   '(RBD) B 454',
#   '(RBD) B 455',
#   '(S2) B 757',
#   '(NTD) C 98'),
#  (0.11413242962188311,
#   0.11811020199490596,
#   0.1186025116576454,
#   0.13107605333495354,
#   0.13266329625028064,
#   0.1554692878263608,
#   0.20105242289947703,
#   0.21207823878987558,
#   0.21932937949434242)]

# %%
negative = [['C 1097 (S2)', -0.28], ['A 155 (NTD)', -0.28], ['B 6 (NTD)', -0.19], ['A 1095 (S2)', -0.16], ['B 624 (linker)', -0.14], ['C 1074 (S2)', -0.13],
['B 607 (linker)', -0.12],['C 1002 (S2)', -0.12], ['B 256 (NTD)', -0.12], ['C 1082 (S2)', -0.11]]

negative = list(zip(*negative))

negative
# Out:
# [('C 1097 (S2)',
#   'A 155 (NTD)',
#   'B 6 (NTD)',
#   'A 1095 (S2)',
#   'B 624 (linker)',
#   'C 1074 (S2)',
#   'B 607 (linker)',
#   'C 1002 (S2)',
#   'B 256 (NTD)',
#   'C 1082 (S2)'),
#  (-0.28, -0.28, -0.19, -0.16, -0.14, -0.13, -0.12, -0.12, -0.12, -0.11)]

# %%
fig, ax = plt.subplots(figsize=(4,4))
ax.tick_params(axis="y",direction="in", pad=-90)
ax.barh(positive[0], positive[1],color='blue')
plt.xlim(-0.3,0.4)
plt.axvline(x=0.0,ls='--',c='k')
plt.axvline(x=0.2,ls='--',c='k')
#plt.xticks(color='white')
plt.savefig('centrality_part_positive.pdf',bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(4,4))
ax.yaxis.tick_right()
ax.tick_params(axis="y",direction="in", pad=-120)
ax.barh(negative[0], negative[1],color='blue')
plt.xlim(-0.3,0.4)
plt.axvline(x=0.0,ls='--',c='k')
plt.axvline(x=-0.2,ls='--',c='k')

plt.savefig('centrality_part_negative.pdf',bbox_inches='tight')

# %%
#fully open

positive = [['(RBD) A 329', 0.13],['(S2/linker) C 713', 0.14],['(S2) A 897', 0.15],['(NTD) B 75', 0.15],['(RBD) A 494', 0.15],['(RBD) A 495', 0.17],
    ['(RBD) C 509', 0.17],['(RBD) A 472', 0.17],['(RBD) A 496', 0.25],['(S2) A 896', 0.30]]



positive = list(zip(*positive))

# %%
negative = [['C 1097 (S2)', -0.29],['B 6 (NTD)', -0.29],['A 155 (NTD)', -0.28],['A 1095 (S2)', -0.16],['C 1082 (S2)', -0.15],['B 624  (linker)', -0.14],
    ['C 1002 (S2)', -0.13],['B 607 (linker)', -0.12],['B 256 (NTD)', -0.11],['C 1074 (S2)', -0.10]]



negative = list(zip(*negative))

# %%
fig, ax = plt.subplots(figsize=(4,4))

ax.tick_params(axis="y",direction="in", pad=-90)

ax.barh(positive[0], positive[1],color='red')

plt.xlim(-0.3,0.4)

plt.axvline(x=0.0,ls='--',c='k')

plt.axvline(x=0.2,ls='--',c='k')

#plt.xticks(color='white')

plt.savefig('centrality_full_positive.pdf',bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(4,4))
ax.yaxis.tick_right()
ax.tick_params(axis="y",direction="in", pad=-120)
ax.barh(negative[0], negative[1],color='red')
plt.xlim(-0.3,0.4)
plt.axvline(x=0.0,ls='--',c='k')
plt.axvline(x=-0.2,ls='--',c='k')

plt.savefig('centrality_full_negative.pdf',bbox_inches='tight')
